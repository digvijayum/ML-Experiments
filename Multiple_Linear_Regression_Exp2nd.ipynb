# %% [markdown]
# <a href="https://colab.research.google.com/github/digvijayum/ML-Experiments/blob/main/Multiple_Linear_Regression_Exp2nd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#create dataset with missing values
# Dataset with Area, Bedrooms (one missing value), Age, and Price
data={
    'Area' : [2600,3000,3200,3600,4000,4100],
    'Bedrooms' : [3,4,None,3,5,6],
    'Age' : [20,15,18,30,8,8],
    'Price' : [550000,565000,610000,595000,760000,810000]
}

# %%
#Convert it into a DataFrame using pandas
df=pd.DataFrame(data)

# %%
#Handle missing data using fillna().
print("Before filling NaN:\n", df)
df.fillna(0, inplace=True) # Replacing missing values with 0
print("\nAfter filling NaN with 0:\n", df)
# Out:
# Before filling NaN:
#     Area  Bedrooms  Age   Price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
#
# After filling NaN with 0:
#     Area  Bedrooms  Age   Price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       0.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
#Plot the heatmap to view feature correlations.
#Heatmap: Feature Correlation
sns.heatmap(df.corr(), annot=True)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#Plot the scatter plot for visualization.
#Scatter Plot: Area vs Price
sns.relplot(x='Area', y='Price', data=df)
plt.title("Area vs Price")
plt.show()
# Independent variables (Area, Bedroom, Age)
X = df[['Area', 'Bedrooms', 'Age']]
# Dependent variable (Price)
y = df['Price']

# %%
#Fit a Multiple Linear Regression model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Print the intercept and coefficients.
# Model parameters
print("\nIntercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 283533.2934236253
# Coefficients: [  131.14854438  1343.68796641 -5332.95320845]

# %%
# Predicting price for a house with Area=3000, Bedroom=3, Age=15)
predicted_price = model.predict([[3000, 3, 15]])
print("\nPredicted Price for Area=3000, Bedroom=3, Age=15:", predicted_price[0])
# Out:
# Predicted Price for Area=3000, Bedroom=3, Age=15: 601015.6923375987
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
